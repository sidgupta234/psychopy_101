# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("test.csv")#, index=False)
dataset.head()
# len(dataset)
# Out:
#    word_1   word_2  condition  WUP_score  correct_incorrect key_pressed  \
# 0   bread   utrtbe          3       0.00                  0           n
# 1   bread   laptop          4       0.20                  1           y
# 2  engine    tairn          2       0.00                  0           n
# 3  doctor  shampoo          4       0.21                  1           y
# 4  engine    train          1       0.63                  1           y
#
#    response_status  reaction_time  age_list
# 0                1    1389.216185        18
# 1                1    1108.018875        18
# 2                1    1035.490990        18
# 3                1     937.063217        18
# 4                1    1017.201900        18

# %%
# Removing magma
# dataset = dataset[dataset.word_1 != 'lava']
# len(dataset)
# Out:
# 1216

# %%
dataset.head()
# Out:
#    Unnamed: 0  word_1   word_2  condition  WUP_score  correct_incorrect  \
# 0           0   bread   utrtbe          3       0.00                  0
# 1           1   bread   laptop          4       0.20                  1
# 2           2  engine    tairn          2       0.00                  0
# 3           3  doctor  shampoo          4       0.21                  1
# 4           4  engine    train          1       0.63                  1
#
#   key_pressed  response_status  reaction_time  age_list
# 0           n                1    1389.216185        18
# 1           y                1    1108.018875        18
# 2           n                1    1035.490990        18
# 3           y                1     937.063217        18
# 4           y                1    1017.201900        18

# %%
dataset.to_csv("test.csv", index=False)

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# ### About participants

# %%
# Average age of participants
groupby_age = dataset.groupby(by=['age_list'])
#groupby_age
print(groupby_age.size()/80)
# Out:
# age_list
# 18    3.0
# 19    4.0
# 20    3.0
# 21    1.0
# 22    2.0
# 23    1.0
# 24    1.0
# 25    1.0
# dtype: float64
