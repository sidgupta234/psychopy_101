# %%
import pandas as pd
data = pd.read_csv("Siddharth_Gupta_22.csv")
data.head()
# Out:
#    word_1   word_2  WUP_score  correct_incorrect key_pressed  response_status  \
# 0   cloth  apaeprl       0.00                  0           y                0
# 1  doctor    nusre       0.00                  0           y                0
# 2     tea   oecfef       0.00                  0           y                0
# 3   cloth  apparel       0.71                  1           y                1
# 4   bread   uretbt       0.00                  0           n                1
#
#    reaction_time  age_list
# 0     848.993063        22
# 1     614.985943        22
# 2     544.198990        22
# 3     871.513128        22
# 4    1152.809143        22

# %%
import pandas as pd
data = pd.read_csv("mahabalesh_javali_23.csv")
data.head(100)
# Out:
#     word_1    word_2  condition  WUP_score  correct_incorrect key_pressed  \
# 0    phone     light          4       0.20                  1           y
# 1   office     jelly          4       0.24                  1           y
# 2    blood  ptaelelt          2       0.00                  0           n
# 3   office     chair          1       0.53                  1           y
# 4    photo    camera          1       0.59                  1           y
# ..     ...       ...        ...        ...                ...         ...
# 75   photo    cmarea          2       0.00                  0           n
# 76   virus  riatcaeb          3       0.00                  0           n
# 77  guitar    voilin          2       0.00                  0           y
# 78  doctor     nruse          2       0.00                  0           n
# 79   shirt    flower          4       0.40                  1           y
#
#     response_status  reaction_time  age_list
# ...
